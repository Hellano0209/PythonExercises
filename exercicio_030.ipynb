# %% [markdown]
# # EXERCÍCIO 030 DO CURSO DE PYTHON
#
# Esse programa recebe um número inteiro e retorna se esse valor é par ou ímpar.

# %%
n = int(input('Entre com um valor inteiro: '))

if n % 2 == 0:
  print('O número {} é par.'.format(n))
else:
  print('O número {} é ímpar.'.format(n))
# Out:
# Entre com um valor inteiro: 20
# O número 20 é par.
