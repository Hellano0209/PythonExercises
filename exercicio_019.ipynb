# %% [markdown]
# # EXERCÍCIO 019 DO CURSO DE PYTHON
#
# Esse programa soteia aleatoriamente o nome de um aluno entre uma lista de quatro alunos que o usuário entrar.

# %%
import random

aluno1 = input('Nome do primeiro aluno: ')
aluno2 = input('Nome do segundo aluno: ')
aluno3 = input('Nome do terceiro aluno: ')
aluno4 = input('Nome do quarto aluno: ')

lista = [aluno1, aluno2, aluno3, aluno4]
escolhido = random.choice(lista)

print('O aluno escolhido foi o(a) {}'.format(escolhido))
# Out:
# Nome do primeiro aluno: Hellano
# Nome do segundo aluno: Elaine
# Nome do terceiro aluno: Hope
# Nome do quarto aluno: Herllan
# O aluno escolhido foi o(a) Elaine
