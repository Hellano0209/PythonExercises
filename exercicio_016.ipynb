# %% [markdown]
# # EXERCÍCIO 016 DO CURSO DE PYTHON
#
# Esse programa ler um número real e retorna a parte inteira.

# %%
import math

n = float(input('Digite um número real: '))
n2 = math.floor(n)

print('A parte inteira do número {} é {}.'.format(n, n2))
# Out:
# Digite um número real: 2.26
# A parte inteira do número 2.26 é 2.
