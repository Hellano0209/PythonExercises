# %% [markdown]
# # EXERCÍCIO 021 DO CURSO DE PYTHON
#
# Esse programa carrega e executa um arquivo mp3.

# %%
import pygame

pygame.mixer.init()
pygame.mixer.music.load('exercicio_021.mp3')
pygame.mixer.music.play()
input()
pygame.event.wait()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-16-435ce27751d1> in <cell line: 3>()
#       1 import pygame
#       2
# ----> 3 pygame.mixer.init()
#       4 pygame.mixer.music.load('exercicio_021.mp3')
#       5 pygame.mixer.music.play()
#
# error: Could not setup connection to PulseAudio
