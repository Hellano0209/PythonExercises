# %% [markdown]
# # EXERCÍCIO 044 DO CURSO DE PYTHON
#
# Esse programa calcula o valor a ser pago por um produto, considerando o seu preço normal e a condição de pagamento.

# %%
preco = float(input('Qual o preço do produto: '))

print('Formas de pagamento:\n[1]À vista dinheiro/cheque\n[2]À vista cartão\n[3]Parcelado em até 2x\n[4]Parcelado 3x ou mais')
opcao = int(input('Qual a opão: '))

if opcao == 1:
  taxa = -0.1
  print('O valor a ser pago com um desconto de 10% é {}.'.format(preco*(1+taxa)))
elif opcao == 2:
  taxa = -0.05
  print('O valor a ser pago com um desconto de 5% é {}.'.format(preco*(1+taxa)))
elif opcao == 3:
  taxa = 0
  print('O valor a ser pago é {}.'.format(preco*(1+taxa)))
else:
  taxa = 0.2
  print('O valor a ser pago com juros é {}.'.format(preco*(1+taxa)))
# Out:
# Qual o preço do produto: 100
# Formas de pagamento:
# [1]À vista dinheiro/cheque
# [2]À vista cartão
# [3]Parcelado em até 2x
# [4]Parcelado 3x ou mais
# Qual a opão: 4
# O valor a ser pago com juros é 120.0.
