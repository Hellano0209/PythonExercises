# %% [markdown]
# # EXERCÍCIO 046 DO CURSO DE PYTHON
#
# Esse programa cria uma contagem regressiva

# %%
from time import sleep

cont = int(input('De quantos segundo você quer que seja a contagem regressiva: '))

for i in range(cont):
  print(i+1)
  sleep(1)

print('BUM BUM POW')
# Out:
# De quantos segundo você quer que seja a contagem regressiva: 5
# 1
# 2
# 3
# 4
# 5
# BUM BUM POW
