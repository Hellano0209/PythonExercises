# %% [markdown]
# # EXERCÍCIO 013 DE PYTHON
#
# Esse programa calcula um reajuste salaria de 15%.

# %%
salario = float(input('Qual o seu salário atual: '))

taxa = 0.15
almento = 0.15*salario
nsalario = salario + almento

print('Você ganha {:.2f}R$, com um almento de 15%, você passa a receber {:.2f}R$. Um almento de {:.2f}R$'.format(salario, nsalario, almento))
# Out:
# Qual o seu salário atual: 2779.92
# Você ganha 2779.92R$, com um almento de 15%, você passa a receber 3196.91R$. Um almento de 416.99R$
